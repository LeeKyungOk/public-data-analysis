# %% [markdown]
# # Seaborn

# %% [markdown]
# <img src = "https://repository-images.githubusercontent.com/4704710/fd110d80-63d1-11eb-9ae4-de7c23c9dedc" height = "200px">

# %% [markdown]
# ## Seaborn 설치 & Library Import

# %%
# !pip install seaborn==0.12.2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 6.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.2
#     Uninstalling seaborn-0.13.2:
#       Successfully uninstalled seaborn-0.13.2
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ## Line Chart

# %% [markdown]
# ### Line Chart 기본 구성

# %%
x = range(1, 11, 1)
y = range(1, 20, 2)

plt.figure()
sns.lineplot(x=x, y=y)
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x = range(1, 11, 1)
y = range(1, 20, 2)

plt.figure(figsize = (6,3))
sns.lineplot(x=x, y=y)
plt.show()

# %% [markdown]
# ### Grid 설정해서 Line Chart 그리기

# %%
cd /content/drive/MyDrive/SeSac_도봉캠퍼스_AI_양수민/chapter4.Data_Handling/data
# Out:
# /content/drive/MyDrive/SeSac_도봉캠퍼스_AI_양수민/chapter4.Data_Handling/data

# %%
import pandas as pd
kospi_df = pd.read_csv('./kospi_data.csv')

# %%
x = kospi_df['date'].iloc[:100]
y = kospi_df['close'].iloc[:100]

# %%
plt.figure()
sns.lineplot(x = x, y= y)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize = (15,3))
sns.lineplot(x=x, y=y)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Line 색상 지정

# %%
plt.figure(figsize = (15,3))
sns.lineplot(data = kospi_df.iloc[:100], x = 'date', y = 'close', color = 'red')
plt.show()

# %% [markdown]
# ### chart theme 변경

# %%
print(sns.axes_style(style = "darkgrid"))
# Out:
# {'figure.facecolor': 'white', 'axes.labelcolor': '.15', 'xtick.direction': 'out', 'ytick.direction': 'out', 'xtick.color': '.15', 'ytick.color': '.15', 'axes.axisbelow': True, 'grid.linestyle': '-', 'text.color': '.15', 'font.family': ['sans-serif'], 'font.sans-serif': ['Arial', 'DejaVu Sans', 'Liberation Sans', 'Bitstream Vera Sans', 'sans-serif'], 'lines.solid_capstyle': 'round', 'patch.edgecolor': 'w', 'patch.force_edgecolor': True, 'image.cmap': 'rocket', 'xtick.top': False, 'ytick.right': False, 'axes.grid': True, 'axes.facecolor': '#EAEAF2', 'axes.edgecolor': 'white', 'grid.color': 'white', 'axes.spines.left': True, 'axes.spines.bottom': True, 'axes.spines.right': True, 'axes.spines.top': True, 'xtick.bottom': False, 'ytick.left': False}

# %%
plt.figure(figsize = (15,3))
sns.set_style('dark')
sns.lineplot(data = kospi_df.iloc[:100], x = 'date', y = 'close', color = 'red')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### Line style / Marker입력

# %%
plt.figure(figsize = (15,3))
sns.lineplot(data = kospi_df.iloc[:100], x = 'date', y = 'close', marker = "o", linestyle = '--')
plt.show()

# %% [markdown]
# #### 여러 그래프 한 차트 화면에 겹쳐 그리기

# %%
plt.figure(figsize = (12,3))

sns.lineplot(data = kospi_df.iloc[:100], x = 'date', y = 'close')
sns.lineplot(data = kospi_df.iloc[:100], x = 'date', y = '5day_MA_close')

plt.grid(True)
plt.show()

# %% [markdown]
# #### 차트 범례(Legend) 작성하기
#
# ```python
# plt.figure()
# sns.plot(x, y)
# sns.lineplot(data = dataframe변수명, x = 'x축칼럼명', y = 'y축칼럼명_1', label = "label명")
#
# sns.lineplot(data = dataframe변수명, x = 'x축칼럼명', y = 'y축칼럼명_2', label = "label명")
#
# plt.legend()
# plt.show()
# ```

# %%
plt.figure(figsize = (12,3))

sns.lineplot(data = kospi_df.iloc[:100], x = 'date', y = 'close', label = 'close_price')
sns.lineplot(data = kospi_df.iloc[:100], x = 'date', y = '5day_MA_close', label = 'MA_5_close_price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Bar Chart

# %% [markdown]
# ### 기본구성

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 15 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 0s (31.4 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import pandas as pd
sales_df = pd.read_csv('./sales_info.csv', encoding = 'cp949')
sales_sum_by_category = sales_df.groupby("상품대분류명").sum()
x = sales_sum_by_category.index
y = sales_sum_by_category['구매금액']
# Out:
# <ipython-input-3-d999544089a1>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales_sum_by_category = sales_df.groupby("상품대분류명").sum()

# %%
plt.figure(figsize = (6,3))

sns.set_style({'font.family' : ["NanumBarunGothic"]})
sns.barplot(data = sales_sum_by_category, x = sales_sum_by_category.index, y = '구매금액')
plt.show()

# %% [markdown]
# ### 수평(barh)차트 그리기

# %%
plt.figure(figsize = (6,3))

sns.set_style({'font.family' : ["NanumBarunGothic"]})
sns.barplot(data = sales_sum_by_category, y = sales_sum_by_category.index, x = '구매금액', orient = 'h')
plt.show()

# %% [markdown]
# ## Scatter plot
#
# ```python
# plt.figure()
# sns.scatterplot(DataFrame변수명, x = 'x축칼럼명', y = 'y축칼럼명')
# plt.show()
# ```

# %%
# !pip install yfinance==0.2.32

import yfinance as yf
start = "2000-01-01"
end = "2020-12-31"
ss_df = yf.download("005930.KS", start, end)
dollar_df = yf.download("USDKRW=X", start, end)
interest_10y_df = yf.download("^TNX", start,end)
# Out:
# ...
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
df = pd.merge(ss_df.loc[:, 'Close'], dollar_df.loc[:, 'Close'], how = 'inner', on = 'Date', suffixes = ('_SS', '_Dollar'))
df = pd.merge(df, interest_10y_df.loc[:, 'Close'], how = 'inner', on = 'Date')
df.rename(columns = {'Close': 'Close_interest_10y'}, inplace = True)

# %%
plt.figure()
sns.scatterplot(x = df['Close_interest_10y'], y= df['Close_SS'])
plt.show()

# %%
plt.figure()
sns.scatterplot(df, x = 'Close_interest_10y', y = 'Close_SS')
plt.show()

# %% [markdown]
# ## Box Plot

# %%
salary_df = pd.read_csv('./ds_salaries.csv')

# %%
plt.figure()
sns.boxplot(salary_df, x = 'experience_level', y = 'salary_in_usd')
plt.show()

# %% [markdown]
# ## Dis Plot

# %%
salary_df = pd.read_csv('./ds_salaries.csv')

# %%
plt.figure()
sns.displot(salary_df, x='salary_in_usd')
plt.show()

# %%
plt.figure()
sns.displot(salary_df, x='salary_in_usd', kde = True)
plt.show()

# %%
salary_df.head()
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
plt.figure()
sns.displot(salary_df, x='salary_in_usd', hue = 'experience_level')
plt.show()

# %%
plt.figure()
sns.displot(salary_df, x='salary_in_usd', hue = 'experience_level', kind = 'kde')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure()
sns.displot(salary_df.loc[salary_df['job_title'] == 'Machine Learning Engineer'], x='salary_in_usd', hue = 'experience_level', kind = 'kde')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
